# %%
import os 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
file_path=os.path.join(os.getcwd() , "clustered" , "clustered_customer_03102025__142942.csv")
df=pd.read_csv(file_path)

# %%
df
# Out:
#           Education Marital_Status   Income  Recency  wines  fruits  meat  \
# 0     Undergraduate          Alone  58138.0       58    635      88   546
# 1     Undergraduate          Alone  46344.0       38     11       1     6
# 2     Undergraduate        Partner  71613.0       26    426      49   127
# 3     Undergraduate        Partner  26646.0       26     11       4    20
# 4               PhD        Partner  58293.0       94    173      43   118
# ...             ...            ...      ...      ...    ...     ...   ...
# 2211  Undergraduate        Partner  61223.0       46    709      43   182
# 2212            PhD        Partner  64014.0       56    406       0    30
# 2213  Undergraduate          Alone  56981.0       91    908      48   217
# 2214   Postgraduate        Partner  69245.0        8    428      30   214
# 2215            PhD        Partner  52869.0       40     84       3    61
#
#       fist  sweets  golds  ...  StorePurchases  NumWebVisitsMonth  \
# ...

# %%
df["Cluster"].value_counts()
# Out:
# Cluster
# 0    781
# 1    737
# 2    698
# Name: count, dtype: int64
